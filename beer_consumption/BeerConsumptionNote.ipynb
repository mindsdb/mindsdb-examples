# %%
import mindsdb
from mindsdb import Predictor

# We tell mindsDB what we want to learn and from what data
Predictor(name='beer_consumption').learn(
    to_predict='Consumo de cerveja', # the column we want to learn to predict given all the data in the file
    from_data="dataset/Consumo_cerveja_train.csv" # the path to the file where we can learn from, (note: can be url)
)
# Out:
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:52 - [START] DataExtractor
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/data_extractor/data_extractor.py:232 - We have split the input data into:
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:57 - [END] DataExtractor, execution time: 0.376 seconds
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:52 - [START] StatsGenerator
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:489 - population_size=357,  sample_size=357  100.00%
#
# WARNING:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:387 - The data in the column Data seems to have too contain too much noise/randomness based on the value variability. That is too say, the data is too unevenly distributed and has too many outliers. Please see the detailed logs bellow for more info.
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Data"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Date: 357
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Temperatura Media"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Float: 349
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -    Int: 8
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Temperatura Minima"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -    Int: 31
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Float: 326
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Temperatura Maxima"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Float: 316
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -    Int: 41
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# WARNING:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:432 - Column Precipitacao is very biased towards the value 0.948, please make sure that the data in this column is correct !
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Precipitacao"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -    Int: 236
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Float: 121
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# WARNING:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:387 - The data in the column Final de Semana seems to have too contain too much noise/randomness based on the value variability. That is too say, the data is too unevenly distributed and has too many outliers. Please see the detailed logs bellow for more info.
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Final de Semana"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Binary Category: 357
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/stats_generator/stats_generator.py:455 - Data distribution for column "Consumo de cerveja"
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:76 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:119 -  Float: 357
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/data_types/mindsdb_logger.py:123 - ----------
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:57 - [END] StatsGenerator, execution time: 0.814 seconds
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:52 - [START] DataTransformer
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:57 - [END] DataTransformer, execution time: 0.421 seconds
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:52 - [START] ModelInterface
#
# WARNING:mindsdb-logger-core-logger:libs/helpers/general_helpers.py:134 - could not check for MindsDB updates
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 20 with an error of 0.59% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 40 with an error of 0.41% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 60 with an error of 0.51% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 80 with an error of 0.58% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 100 with an error of 0.36% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 120 with an error of 0.37% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 140 with an error of 0.31% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 160 with an error of 0.34% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 180 with an error of 0.31% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 200 with an error of 0.31% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 220 with an error of 0.33% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 240 with an error of 0.3% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 260 with an error of 0.37% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 280 with an error of 0.27% on the testing dataset
#
# DEBUG:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:137 - We've reached training epoch nr 300 with an error of 0.42% on the testing dataset
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/backends/lightwood.py:163 - Training accuracy of: {'Consumo de cerveja': 0.21740533599678788}
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:57 - [END] ModelInterface, execution time: 8.955 seconds
#
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:52 - [START] ModelAnalyzer
#
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (6). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1450377792.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1423415808.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1423966176.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (4). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1422947520.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1447299360.0, please make sure that the data in this column is correct !
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1424969280.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1429413696.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (2). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1432873152.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (3). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Column Data is very biased towards the value 1429707456.0, please make sure that the data in this column is correct !
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# Can't disable output on Jupyter notebook
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/scipy/stats/stats.py:2315: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /home/zoran/MyProjects/mindsdb-examples/mindsdb/lib/python3.7/site-packages/sklearn/neighbors/lof.py:253: UserWarning: n_neighbors (20) is greater than the total number of samples (1). n_neighbors will be set to (n_samples - 1) for estimation.
#   % (self.n_neighbors, n_samples))
# Can't disable output on Jupyter notebook
# INFO:mindsdb-logger-5cf2b646-c9bd-11e9-ad83-f0d5bfaec0a9:libs/phases/base_module.py:57 - [END] ModelAnalyzer, execution time: 0.744 seconds

# %%
from mindsdb import Predictor

# use the model to make predictions
result = Predictor(name='beer_consumption').predict(when={'Temperatura Media': '27.3','Final de Semana': 0, 'Precipitacao': '1.2'})
print(result[0])
# Out:
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:52 - [START] DataExtractor
#
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:57 - [END] DataExtractor, execution time: 0.069 seconds
#
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:52 - [START] DataTransformer
#
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:57 - [END] DataTransformer, execution time: 0.195 seconds
#
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:52 - [START] ModelInterface
#
# INFO:mindsdb-logger-core-logger:libs/phases/base_module.py:57 - [END] ModelInterface, execution time: 0.046 seconds
# * We are 23% confident the value of "Consumo de cerveja" lies between 24.1 and 24.1 and We are 20% confident the value of "Consumo de cerveja" lies between 22.4 and 22.4 and We are 14% confident the value of "Consumo de cerveja" lies between 18.9 and 18.9 and We are 13% confident the value of "Consumo de cerveja" lies between 31.5 and 31.5.
# WARNING:mindsdb-logger-core-logger:libs/helpers/general_helpers.py:134 - could not check for MindsDB updates
