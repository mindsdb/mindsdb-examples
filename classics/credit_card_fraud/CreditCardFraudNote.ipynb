# %%
import mindsdb

# Instantiate a mindsdb Predictor
mdb = mindsdb.Predictor(name='cc-fraud')

# We tell the Predictor what column or key we want to learn and from what data
mdb.learn(
    from_data="dataset/creditcard-train.csv", # the path to the file where we can learn from, (note: can be url)
    to_predict='Class', # the column we want to learn to predict given all the data in the file
)
# Out:
# INFO:mindsdb-logger-93499f14-f0e7-11e9-bd8c-54e1ad558569:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:52 - [START] DataExtractor
#
# INFO:mindsdb-logger-93499f14-f0e7-11e9-bd8c-54e1ad558569:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\data_extractor\data_extractor.py:238 - We have split the input data into:
#
# INFO:mindsdb-logger-93499f14-f0e7-11e9-bd8c-54e1ad558569:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:57 - [END] DataExtractor, execution time: 75.970 seconds
#
# INFO:mindsdb-logger-93499f14-f0e7-11e9-bd8c-54e1ad558569:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:52 - [START] StatsGenerator
#
# INFO:mindsdb-logger-93499f14-f0e7-11e9-bd8c-54e1ad558569:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\stats_generator\stats_generator.py:489 - population_size=284803,  sample_size=284803  100.00%
#
# ...

# %%
from mindsdb import Predictor

#predict inputs 
p1 = {'Time': '23', 'V1': '1.32270726911234', 'V2': '-0.17404083293642',
     'V3': '0.434555031250987', 'V28': '0.0288223002307744', 'V27': '0.042335257639718', 'Amount': '16'}
p2 = {'Time': '24', 'V1': '1.23742903021294', 'V2': '0.0610425841868962',
     'V3': '0.380525879794222', 'V28': '0.011836231430416', 'Amount': '17.28'}
p3 ={ 'V1' : '-0.88525408859895', 'V2': '1.79064923163963', 'V3': '-0.945148961205205', 'Amount' : '757',
'V28': '0.176735548819463', 'V27': '0.506892694941992', 'Time': '81372'}


# use the model to make predictions
result = Predictor(name='cc-fraud').predict(when=p3)
print(result[0])
# Out:
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:52 - [START] DataExtractor
#
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:57 - [END] DataExtractor, execution time: 0.356 seconds
#
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:52 - [START] DataTransformer
#
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:57 - [END] DataTransformer, execution time: 0.440 seconds
#
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:52 - [START] ModelInterface
#
# INFO:mindsdb-logger-core-logger:f:\sudhanshu\opensourceprojects\mindsdb\mindsdb\libs\phases\base_module.py:57 - [END] ModelInterface, execution time: 1.148 seconds
# * We are 80% confident the value of "Class" is 0.
